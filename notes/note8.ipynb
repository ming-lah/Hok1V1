# %% [markdown]
# ### **英雄部分设计**
#
#
# #### **各种配置id**
#
# 目前通过模拟出现了大量的技能和buff的id，具体梳理如下，之后的开发可以考虑使用。当前将buff以及技能标志相关的内容输出到了日志中，可以方便查看。
#
# 下面给出一个梳理：
#
# 1. 技能部分
#
# | slot\_type     | 典型 cfg                  | 含义（经验归纳）             | 日志里的典型 CD                |
# | -------------- | ----------------------- | -------------------- | ------------------------ |
# | `SLOT_SKILL_0` | 11100/11101/11102/11103 | **被动/普攻/强化普攻**（不同分支或形态） | `0/825`、`792/825`…（普攻间隔） |
# | `SLOT_SKILL_1` | 11110                   | 1技能                  | `4967/5000`（≈5s）         |
# | `SLOT_SKILL_2` | 11120                   | 2技能                  | `0/8000`（≈8s）            |
# | `SLOT_SKILL_3` | 11130                   | 大招                   | `24967/25000`（≈25s）      |
# | `SLOT_SKILL_4` | 90003                   | 恢复技能             | `59967/60000`（≈60s）      |
# | `SLOT_SKILL_5` | 80115                   | 召唤师技能(闪现)                 | `119967/120000`（≈120s）   |
#
# 2. buff部分
